# %%
employees = [
    {"id": 101, "name": "Anuj", "salary": 80000},
    {"id": 102, "name": "Raj", "salary": 65000},
    {"id": 103, "name": "Priya", "salary": 95000},
    {"id": 104, "name": "Amit", "salary": 72000}
]

print(list(map(lambda x:x["salary"],employees)))
# Out:
# [80000, 65000, 95000, 72000]

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# {"name": "Anuj", "salary": 80000, "annual_bonus": 8000}
result = []
for i in employees:
    d = {}
    d["name"] = i["name"]
    d["salary"] = i["salary"]
    d["annual_bonus"] = i["salary"]* 0.1
    result.append(d)
print(result)
# Out:
# [{'name': 'Anuj', 'salary': 80000, 'annual_bonus': 8000.0}, {'name': 'Raj', 'salary': 65000, 'annual_bonus': 6500.0}, {'name': 'Priya', 'salary': 95000, 'annual_bonus': 9500.0}, {'name': 'Amit', 'salary': 72000, 'annual_bonus': 7200.0}]

# %%
result = (map(lambda x : {"name": x["name"], "salary": x["salary"]},employees))

print(next(result))
print(next(result))
print(next(result))
print(next(result))

result = (map(lambda x : {"name": x["name"], "salary": x["salary"]},employees))

print(list(result))
# Out:
# {'name': 'Anuj', 'salary': 80000}
# {'name': 'Raj', 'salary': 65000}
# {'name': 'Priya', 'salary': 95000}
# {'name': 'Amit', 'salary': 72000}
# [{'name': 'Anuj', 'salary': 80000}, {'name': 'Raj', 'salary': 65000}, {'name': 'Priya', 'salary': 95000}, {'name': 'Amit', 'salary': 72000}]

# %%
# employees earning more than 75000
from functools import reduce
result = (map(lambda x : {"name": x["name"], "salary": x["salary"]},employees))

max_salary = filter(lambda x: x["salary"] >75000,result)

print((list(max_salary)))
# Out:
# [{'name': 'Anuj', 'salary': 80000}, {'name': 'Priya', 'salary': 95000}]

# %%
# salary > 70000 AND employee name starts with "A"
employees = [
    {"id": 101, "name": "Anuj", "salary": 80000},
    {"id": 102, "name": "Raj", "salary": 65000},
    {"id": 103, "name": "Priya", "salary": 95000},
    {"id": 104, "name": "Amit", "salary": 72000}
]
result = (map(lambda x : {"name": x["name"], "salary": x["salary"]},employees))

max_salary = filter(lambda x: x["salary"] >70000 and x["name"].split()[0][0] == "A",result)

print((list(max_salary)))
# Out:
# [{'name': 'Anuj', 'salary': 80000}, {'name': 'Amit', 'salary': 72000}]

# %%
emp = [{'name': 'Anuj', 'salary': 80000}, {'name': 'Priya', 'salary': 95000}]
emp[0]["name"].split()[0][0]
# Out:
# 'A'

# %%
# total salary
from functools import reduce
result = list(map(lambda x : x["salary"],employees))
print(result)
total_salary = reduce(lambda x,y: x+y , result)
print(total_salary)
# Out:
# [80000, 65000, 95000, 72000]
# 312000

# %%
total_salary = reduce(lambda x,y: x+y["salary"] , employees,0)
print(total_salary)
# Out:
# 312000

# %%
#find highest salary

max_salary = reduce(lambda x,y: x if x["salary"] > y["salary"] else y,employees)
print(max_salary)
# Out:
# {'id': 103, 'name': 'Priya', 'salary': 95000}

# %%
# Get names of high earners , employees earning > 75000 , and extract their names
employees = [
    {"id": 101, "name": "Anuj", "salary": 80000},
    {"id": 102, "name": "Raj", "salary": 65000},
    {"id": 103, "name": "Priya", "salary": 95000},
    {"id": 104, "name": "Amit", "salary": 72000}
]
max_salary = filter(lambda x: x["salary"]>75000, employees)

# names = list(map(lambda x : x["name"],max_salary))
# print(names)

# get only salaries of earners

salary = list(map(lambda x : x["salary"],max_salary))
print(salary)
# Out:
# [80000, 95000]

# %%
# Q11. Give high earners a 15% increment

# Only employees earning more than 70000 should receive the increment.

employees = [
    {"id": 101, "name": "Anuj", "salary": 80000},
    {"id": 102, "name": "Raj", "salary": 65000},
    {"id": 103, "name": "Priya", "salary": 95000},
    {"id": 104, "name": "Amit", "salary": 72000}
]
max_salary = filter(lambda x: x["salary"]>70000, employees)

increment = map(lambda x: {"id": x["id"], "name": x["name"], "salary": x["salary"],"increment": x["salary"]*0.15},max_salary)

total_salary = map(lambda x: {"id": x["id"], "name": x["name"], "salary": x["salary"]+x["increment"]},increment)

import pandas as pd
# print(list(total_salary))
df = pd.DataFrame(total_salary)
df
# Out:
#     id   name    salary
# 0  101   Anuj   92000.0
# 1  103  Priya  109250.0
# 2  104   Amit   82800.0

# %%
orders = [
    {
        "order_id": 1,
        "customer": "Anuj",
        "country": "IN",
        "amount": 5000,
        "status": "completed"
    },
    {
        "order_id": 2,
        "customer": "Raj",
        "country": "US",
        "amount": 12000,
        "status": "completed"
    },
    {
        "order_id": 3,
        "customer": "Priya",
        "country": "IN",
        "amount": 3000,
        "status": "cancelled"
    },
    {
        "order_id": 4,
        "customer": "Amit",
        "country": "IN",
        "amount": 15000,
        "status": "completed"
    },
    {
        "order_id": 5,
        "customer": "John",
        "country": "US",
        "amount": 8000,
        "status": "completed"
    }
]

# %%
#  Remove cancelled orders
df = pd.DataFrame(orders)
# Out:
#    order_id customer country  amount     status
# 0         1     Anuj      IN    5000  completed
# 1         2      Raj      US   12000  completed
# 2         3    Priya      IN    3000  cancelled
# 3         4     Amit      IN   15000  completed
# 4         5     John      US    8000  completed

# %%
#completed_orders = filter(lambda x: x["status"] != "cancelled",orders)
df = pd.DataFrame(completed_orders)
df
# Out:
#    order_id customer country  amount     status
# 0         1     Anuj      IN    5000  completed
# 1         2      Raj      US   12000  completed
# 2         4     Amit      IN   15000  completed
# 3         5     John      US    8000  completed

# %%
#Calculate total Indian revenue
indian_revenue = reduce(lambda acc, order: acc+order["amount"] if order["country"] == "IN"  and order["status"] =="completed" else acc,orders,0)
# Out:
# 20000

# %%
# largest completed order

largest_order = reduce(lambda x,y : x if x["amount"] > y["amount"] else y,orders)
print(largest_order)
# Out:
# {'order_id': 4, 'customer': 'Amit', 'country': 'IN', 'amount': 15000, 'status': 'completed'}

# %%
df
# Out:
#           0
# 0  order_id
# 1  customer
# 2   country
# 3    amount
# 4    status

# %%
# Calculate average completed order value
# total / count

completed_orders = [o for o in orders if o["status"] == "completed"]
avg_completed = sum(o["amount"] for o in completed_orders) / len(completed_orders)

print(avg_completed)  # Output: 10000.0  (40000 / 4)
# Out:
# 10000.0

# %%
events = [
    {
        "event_id": 1,
        "user": {
            "id": 101,
            "name": "Anuj"
        },
        "event_type": "purchase",
        "metadata": {
            "amount": 5000,
            "currency": "INR"
        }
    },
    {
        "event_id": 2,
        "user": {
            "id": 102,
            "name": "Raj"
        },
        "event_type": "login",
        "metadata": {
            "amount": 0,
            "currency": "INR"
        }
    },
    {
        "event_id": 3,
        "user": {
            "id": 103,
            "name": "Priya"
        },
        "event_type": "purchase",
        "metadata": {
            "amount": 12000,
            "currency": "INR"
        }
    }
]

# %%
user_id = map(lambda x : x["user"]["id"],events)
print(list(user_id))
# Out:
# [101, 102, 103]

# %%
# extract purchase amounts
purchase = filter(lambda x: x["metadata"]["amount"] >0 , events)
# purchase_amount = map(lambda x:x["metadata"]["amount"],purchase)
# print(sum(purchase_amount))

# %%
# customers who made purchase
customers = map(lambda x:x["user"]["name"],purchase)
print(list(customers))
# Out:
# ['Anuj', 'Priya']

# %%
# {
#     "event_id": 1,
#     "user_id": 101,
#     "user_name": "Anuj",
#     "event_type": "purchase",
#     "amount": 5000,
#     "currency": "INR"
# }

# %%
flatenned = map(lambda x : {"event_id": x["event_id"],"user_id": x["user"]["id"], "user_name": x["user"]["name"],"event_type":x["event_type"],"amount": x["metadata"]["amount"],"currency": x["metadata"]["currency"]},events)
df = pd.DataFrame(flatenned)

# %%
df
# Out:
#    event_id  user_id user_name event_type  amount currency
# 0         1      101      Anuj   purchase    5000      INR
# 1         2      102       Raj      login       0      INR
# 2         3      103     Priya   purchase   12000      INR

# %%
events = [
    {
        "event": {
            "event_id": "EVT-10001",
            "event_type": "ORDER_CREATED",
            "timestamp": "2026-08-29T10:30:45Z",
            "source": {
                "application": "mobile",
                "version": "5.8.1",
                "device": {
                    "type": "iPhone",
                    "os": "iOS",
                    "os_version": "18.6"
                }
            }
        },
        "order": {
            "order_id": "ORD-10001",
            "order_date": "2026-08-29",
            "status": "CONFIRMED",
            "currency": "INR",
            "customer": {
                "customer_id": "CUST-501",
                "name": {
                    "first": "Anuj",
                    "middle": "Kumar",
                    "last": "Verma"
                },
                "contact": {
                    "email": "anuj@example.com",
                    "phone": "+91-9999999999"
                },
                "addresses": {
                    "billing": {
                        "city": "Bengaluru",
                        "state": "Karnataka",
                        "country": "India",
                        "pincode": "560001"
                    },
                    "shipping": {
                        "city": "Bengaluru",
                        "state": "Karnataka",
                        "country": "India",
                        "pincode": "560025"
                    }
                }
            },
            "payment": {
                "payment_id": "PAY-50001",
                "method": "CREDIT_CARD",
                "status": "SUCCESS",
                "amount": {
                    "subtotal": 45000,
                    "discount": 5000,
                    "tax": 7200,
                    "shipping": 500,
                    "total": 47700
                }
            },
            "items": [
                {
                    "item_id": "ITEM-001",
                    "product": {
                        "product_id": "P-1001",
                        "name": "MacBook Pro",
                        "category": {
                            "level_1": "Electronics",
                            "level_2": "Computers",
                            "level_3": "Laptops"
                        },
                        "brand": "Apple"
                    },
                    "quantity": 1,
                    "unit_price": 45000,
                    "attributes": {
                        "color": "Space Black",
                        "storage": "512GB",
                        "ram": "16GB"
                    }
                },
                {
                    "item_id": "ITEM-002",
                    "product": {
                        "product_id": "P-2001",
                        "name": "USB-C Hub",
                        "category": {
                            "level_1": "Electronics",
                            "level_2": "Accessories",
                            "level_3": "Adapters"
                        },
                        "brand": "Belkin"
                    },
                    "quantity": 2,
                    "unit_price": 2500,
                    "attributes": {
                        "color": "Silver",
                        "ports": 8
                    }
                }
            ],
            "coupons": [
                {
                    "code": "WELCOME10",
                    "type": "PERCENTAGE",
                    "value": 10
                }
            ]
        },
        "metadata": {
            "request_id": "REQ-10001",
            "correlation_id": "CORR-10001",
            "environment": "production",
            "tags": ["mobile", "new_customer", "high_value"]
        }
    },

    {
        "event": {
            "event_id": "EVT-10002",
            "event_type": "ORDER_UPDATED",
            "timestamp": "2026-08-29T11:15:20Z",
            "source": {
                "application": "web",
                "version": "8.2.0",
                "device": {
                    "type": "MacBook",
                    "os": "macOS",
                    "os_version": "15.6"
                }
            }
        },
        "order": {
            "order_id": "ORD-10002",
            "order_date": "2026-08-29",
            "status": "SHIPPED",
            "currency": "INR",
            "customer": {
                "customer_id": "CUST-502",
                "name": {
                    "first": "Rahul",
                    "last": "Sharma"
                },
                "contact": {
                    "email": "rahul@example.com"
                }
            },
            "payment": {
                "payment_id": "PAY-50002",
                "method": "UPI",
                "status": "SUCCESS",
                "amount": {
                    "subtotal": 12000,
                    "discount": 1000,
                    "tax": 1980,
                    "shipping": 0,
                    "total": 12980
                }
            },
            "items": [
                {
                    "item_id": "ITEM-003",
                    "product": {
                        "product_id": "P-3001",
                        "name": "Mechanical Keyboard",
                        "category": {
                            "level_1": "Electronics",
                            "level_2": "Accessories"
                        },
                        "brand": "Keychron"
                    },
                    "quantity": 1,
                    "unit_price": 12000,
                    "attributes": {
                        "switch": "Brown",
                        "layout": "US"
                    }
                }
            ],
            "coupons": []
        },
        "metadata": {
            "request_id": "REQ-10002",
            "correlation_id": "CORR-10002",
            "environment": "production",
            "tags": ["web", "returning_customer"]
        }
    },

    {
        "event": {
            "event_id": "EVT-10003",
            "event_type": "ORDER_CANCELLED",
            "timestamp": "2026-08-29T12:05:10Z",
            "source": {
                "application": "mobile",
                "version": "5.8.1",
                "device": {
                    "type": "Android",
                    "os": "Android",
                    "os_version": "15"
                }
            }
        },
        "order": {
            "order_id": "ORD-10003",
            "order_date": "2026-08-29",
            "status": "CANCELLED",
            "currency": "INR",
            "customer": {
                "customer_id": "CUST-503",
                "name": {
                    "first": "Priya",
                    "last": "Singh"
                },
                "contact": {
                    "email": "priya@example.com",
                    "phone": "+91-8888888888"
                }
            },
            "payment": {
                "payment_id": "PAY-50003",
                "method": "CREDIT_CARD",
                "status": "REFUNDED",
                "amount": {
                    "subtotal": 8500,
                    "discount": 500,
                    "tax": 1440,
                    "shipping": 200,
                    "total": 9640
                }
            },
            "items": [
                {
                    "item_id": "ITEM-004",
                    "product": {
                        "product_id": "P-4001",
                        "name": "Headphones",
                        "category": {
                            "level_1": "Electronics",
                            "level_2": "Audio",
                            "level_3": "Headphones"
                        },
                        "brand": "Sony"
                    },
                    "quantity": 1,
                    "unit_price": 8500,
                    "attributes": {
                        "color": "White",
                        "wireless": True
                    }
                }
            ],
            "coupons": [
                {
                    "code": "FESTIVE500",
                    "type": "FIXED",
                    "value": 500
                }
            ]
        },
        "metadata": {
            "request_id": "REQ-10003",
            "correlation_id": "CORR-10003",
            "environment": "production",
            "tags": ["mobile", "cancelled"]
        }
    },

    {
        "event": {
            "event_id": "EVT-10004",
            "event_type": "ORDER_CREATED",
            "timestamp": "2026-08-29T13:40:30Z",
            "source": {
                "application": "web",
                "version": "8.2.0",
                "device": {
                    "type": "Windows",
                    "os": "Windows",
                    "os_version": "11"
                }
            }
        },
        "order": {
            "order_id": "ORD-10004",
            "order_date": "2026-08-29",
            "status": "CONFIRMED",
            "currency": "INR",
            "customer": {
                "customer_id": "CUST-504",
                "name": {
                    "first": "Vikram",
                    "last": "Patel"
                },
                "contact": {
                    "email": "vikram@example.com"
                }
            },
            "payment": {
                "payment_id": "PAY-50004",
                "method": "NET_BANKING",
                "status": "SUCCESS",
                "amount": {
                    "subtotal": 32000,
                    "discount": 3000,
                    "tax": 5220,
                    "shipping": 500,
                    "total": 34720
                }
            },
            "items": [
                {
                    "item_id": "ITEM-005",
                    "product": {
                        "product_id": "P-5001",
                        "name": "Monitor",
                        "category": {
                            "level_1": "Electronics",
                            "level_2": "Computers",
                            "level_3": "Monitors"
                        },
                        "brand": "Dell"
                    },
                    "quantity": 2,
                    "unit_price": 16000,
                    "attributes": {
                        "size": "27 inch",
                        "resolution": "4K"
                    }
                }
            ],
            "coupons": []
        },
        "metadata": {
            "request_id": "REQ-10004",
            "correlation_id": "CORR-10004",
            "environment": "production",
            "tags": ["web", "high_value"]
        }
    },

    {
        "event": {
            "event_id": "EVT-10005",
            "event_type": "PAYMENT_FAILED",
            "timestamp": "2026-08-29T14:25:45Z",
            "source": {
                "application": "mobile",
                "version": "5.8.2",
                "device": {
                    "type": "iPhone",
                    "os": "iOS",
                    "os_version": "18.6"
                }
            }
        },
        "order": {
            "order_id": "ORD-10005",
            "order_date": "2026-08-29",
            "status": "PAYMENT_PENDING",
            "currency": "INR",
            "customer": {
                "customer_id": "CUST-505",
                "name": {
                    "first": "Sneha",
                    "last": "Rao"
                },
                "contact": {
                    "email": "sneha@example.com"
                }
            },
            "payment": {
                "payment_id": "PAY-50005",
                "method": "UPI",
                "status": "FAILED",
                "failure": {
                    "code": "UPI_TIMEOUT",
                    "message": "Payment gateway timeout",
                    "retryable": True
                },
                "amount": {
                    "subtotal": 5000,
                    "discount": 0,
                    "tax": 900,
                    "shipping": 100,
                    "total": 6000
                }
            },
            "items": [
                {
                    "item_id": "ITEM-006",
                    "product": {
                        "product_id": "P-6001",
                        "name": "Smart Watch",
                        "category": {
                            "level_1": "Electronics",
                            "level_2": "Wearables",
                            "level_3": "Smart Watches"
                        },
                        "brand": "Samsung"
                    },
                    "quantity": 1,
                    "unit_price": 5000,
                    "attributes": {
                        "color": "Black",
                        "size": "44mm"
                    }
                }
            ],
            "coupons": []
        },
        "metadata": {
            "request_id": "REQ-10005",
            "correlation_id": "CORR-10005",
            "environment": "production",
            "tags": ["mobile", "payment_failed"]
        }
    },

    {
        "event": {
            "event_id": "EVT-10006",
            "event_type": "ORDER_SHIPPED",
            "timestamp": "2026-08-29T15:10:15Z",
            "source": {
                "application": "web",
                "version": "8.2.1",
                "device": {
                    "type": "Linux",
                    "os": "Ubuntu",
                    "os_version": "24.04"
                }
            }
        },
        "order": {
            "order_id": "ORD-10006",
            "order_date": "2026-08-28",
            "status": "SHIPPED",
            "currency": "INR",
            "customer": {
                "customer_id": "CUST-506",
                "name": {
                    "first": "Arjun",
                    "last": "Mehta"
                },
                "contact": {
                    "email": "arjun@example.com"
                }
            },
            "payment": {
                "payment_id": "PAY-50006",
                "method": "CREDIT_CARD",
                "status": "SUCCESS",
                "amount": {
                    "subtotal": 18000,
                    "discount": 2000,
                    "tax": 2880,
                    "shipping": 300,
                    "total": 19180
                }
            },
            "items": [
                {
                    "item_id": "ITEM-007",
                    "product": {
                        "product_id": "P-7001",
                        "name": "Gaming Mouse",
                        "category": {
                            "level_1": "Electronics",
                            "level_2": "Gaming",
                            "level_3": "Mouse"
                        },
                        "brand": "Logitech"
                    },
                    "quantity": 3,
                    "unit_price": 6000,
                    "attributes": {
                        "color": "Black",
                        "dpi": 16000,
                        "wireless": True
                    }
                }
            ],
            "shipping": {
                "carrier": {
                    "name": "FedEx",
                    "service": "EXPRESS",
                    "tracking": {
                        "tracking_id": "FDX100006",
                        "url": "https://example.com/track/FDX100006"
                    }
                },
                "estimated_delivery": {
                    "date": "2026-09-01",
                    "time_window": {
                        "from": "10:00",
                        "to": "17:00"
                    }
                }
            },
            "coupons": [
                {
                    "code": "GAME2000",
                    "type": "FIXED",
                    "value": 2000
                }
            ]
        },
        "metadata": {
            "request_id": "REQ-10006",
            "correlation_id": "CORR-10006",
            "environment": "production",
            "tags": ["web", "gaming"]
        }
    },

    {
        "event": {
            "event_id": "EVT-10007",
            "event_type": "ORDER_DELIVERED",
            "timestamp": "2026-08-29T16:20:00Z",
            "source": {
                "application": "mobile",
                "version": "5.8.2",
                "device": {
                    "type": "Android",
                    "os": "Android",
                    "os_version": "14"
                }
            }
        },
        "order": {
            "order_id": "ORD-10007",
            "order_date": "2026-08-25",
            "status": "DELIVERED",
            "currency": "INR",
            "customer": {
                "customer_id": "CUST-507",
                "name": {
                    "first": "Karan",
                    "last": "Joshi"
                },
                "contact": {
                    "email": "karan@example.com"
                }
            },
            "payment": {
                "payment_id": "PAY-50007",
                "method": "COD",
                "status": "SUCCESS",
                "amount": {
                    "subtotal": 3000,
                    "discount": 300,
                    "tax": 486,
                    "shipping": 100,
                    "total": 3286
                }
            },
            "items": [
                {
                    "item_id": "ITEM-008",
                    "product": {
                        "product_id": "P-8001",
                        "name": "Running Shoes",
                        "category": {
                            "level_1": "Fashion",
                            "level_2": "Footwear",
                            "level_3": "Sports"
                        },
                        "brand": "Nike"
                    },
                    "quantity": 1,
                    "unit_price": 3000,
                    "attributes": {
                        "size": 9,
                        "color": "Blue"
                    }
                }
            ],
            "coupons": []
        },
        "metadata": {
            "request_id": "REQ-10007",
            "correlation_id": "CORR-10007",
            "environment": "production",
            "tags": ["mobile", "delivered"]
        }
    },

    {
        "event": {
            "event_id": "EVT-10008",
            "event_type": "REFUND_REQUESTED",
            "timestamp": "2026-08-29T17:05:35Z",
            "source": {
                "application": "web",
                "version": "8.3.0",
                "device": {
                    "type": "MacBook",
                    "os": "macOS",
                    "os_version": "15.6"
                }
            }
        },
        "order": {
            "order_id": "ORD-10008",
            "order_date": "2026-08-20",
            "status": "REFUND_REQUESTED",
            "currency": "INR",
            "customer": {
                "customer_id": "CUST-508",
                "name": {
                    "first": "Neha",
                    "last": "Gupta"
                },
                "contact": {
                    "email": "neha@example.com"
                }
            },
            "payment": {
                "payment_id": "PAY-50008",
                "method": "CREDIT_CARD",
                "status": "REFUND_PENDING",
                "amount": {
                    "subtotal": 15000,
                    "discount": 1500,
                    "tax": 2430,
                    "shipping": 300,
                    "total": 16230
                }
            },
            "items": [
                {
                    "item_id": "ITEM-009",
                    "product": {
                        "product_id": "P-9001",
                        "name": "Tablet",
                        "category": {
                            "level_1": "Electronics",
                            "level_2": "Computers",
                            "level_3": "Tablets"
                        },
                        "brand": "Samsung"
                    },
                    "quantity": 1,
                    "unit_price": 15000,
                    "attributes": {
                        "storage": "256GB",
                        "color": "Gray"
                    }
                }
            ],
            "refund": {
                "reason": "DAMAGED",
                "requested_amount": 16230,
                "requested_by": "customer"
            },
            "coupons": []
        },
        "metadata": {
            "request_id": "REQ-10008",
            "correlation_id": "CORR-10008",
            "environment": "production",
            "tags": ["web", "refund"]
        }
    },

    {
        "event": {
            "event_id": "EVT-10009",
            "event_type": "ORDER_CREATED",
            "timestamp": "2026-08-29T18:15:45Z",
            "source": {
                "application": "mobile",
                "version": "5.9.0",
                "device": {
                    "type": "iPhone",
                    "os": "iOS",
                    "os_version": "18.6"
                }
            }
        },
        "order": {
            "order_id": "ORD-10009",
            "order_date": "2026-08-29",
            "status": "CONFIRMED",
            "currency": "INR",
            "customer": {
                "customer_id": "CUST-509",
                "name": {
                    "first": "Riya",
                    "last": "Kapoor"
                },
                "contact": {
                    "email": "riya@example.com"
                }
            },
            "payment": {
                "payment_id": "PAY-50009",
                "method": "UPI",
                "status": "SUCCESS",
                "amount": {
                    "subtotal": 75000,
                    "discount": 7500,
                    "tax": 12150,
                    "shipping": 500,
                    "total": 80150
                }
            },
            "items": [
                {
                    "item_id": "ITEM-010",
                    "product": {
                        "product_id": "P-10001",
                        "name": "iPhone",
                        "category": {
                            "level_1": "Electronics",
                            "level_2": "Mobiles",
                            "level_3": "Smartphones"
                        },
                        "brand": "Apple"
                    },
                    "quantity": 1,
                    "unit_price": 75000,
                    "attributes": {
                        "storage": "256GB",
                        "color": "Midnight"
                    }
                }
            ],
            "coupons": [
                {
                    "code": "IPHONE7500",
                    "type": "FIXED",
                    "value": 7500
                }
            ]
        },
        "metadata": {
            "request_id": "REQ-10009",
            "correlation_id": "CORR-10009",
            "environment": "production",
            "tags": ["mobile", "high_value", "premium"]
        }
    },

    {
        "event": {
            "event_id": "EVT-10010",
            "event_type": "ORDER_UPDATED",
            "timestamp": "2026-08-29T19:00:10Z",
            "source": {
                "application": "web",
                "version": "8.3.0",
                "device": {
                    "type": "Windows",
                    "os": "Windows",
                    "os_version": "11"
                }
            }
        },
        "order": {
            "order_id": "ORD-10010",
            "order_date": "2026-08-29",
            "status": "PROCESSING",
            "currency": "INR",
            "customer": {
                "customer_id": "CUST-510",
                "name": {
                    "first": "Amit",
                    "last": "Nair"
                },
                "contact": {
                    "email": "amit@example.com"
                }
            },
            "payment": {
                "payment_id": "PAY-50010",
                "method": "NET_BANKING",
                "status": "SUCCESS",
                "amount": {
                    "subtotal": 22000,
                    "discount": 2000,
                    "tax": 3600,
                    "shipping": 250,
                    "total": 23850
                }
            },
            "items": [
                {
                    "item_id": "ITEM-011",
                    "product": {
                        "product_id": "P-11001",
                        "name": "Office Chair",
                        "category": {
                            "level_1": "Furniture",
                            "level_2": "Office",
                            "level_3": "Chairs"
                        },
                        "brand": "Featherlite"
                    },
                    "quantity": 1,
                    "unit_price": 22000,
                    "attributes": {
                        "color": "Black",
                        "material": "Mesh"
                    }
                }
            ],
            "coupons": []
        },
        "metadata": {
            "request_id": "REQ-10010",
            "correlation_id": "CORR-10010",
            "environment": "production",
            "tags": ["web", "office"]
        }
    }
]

# %%
# Event
# "event": {
#         "event_id": "EVT-984321",
#         "event_type": "ORDER_CREATED",
#         "timestamp": "2026-08-29T10:30:45Z",
#         "source": {
#             "application": "mobile",
#             "version": "5.8.1",
#             "device": {
#                 "type": "iPhone",
#                 "os": "iOS",
#                 "os_version": "18.6"
#             }
#         }
#     }

# | Column              | Example              |
# | ------------------- | -------------------- |
# | event_id            | EVT-984321           |
# | event_type          | ORDER_CREATED        |
# | event_timestamp     | 2026-08-29T10:30:45Z |
# | application         | mobile               |
# | application_version | 5.8.1                |
# | device_type         | iPhone               |
# | device_os           | iOS                  |
# | device_os_version   | 18.6                 |

# %%
# order_event = map(lambda x: {"event_id": x["event_id"],"event_type":x["event_type"],"event_timestamp": x["timestamp"]},order)
# print(list(order_event))

# %%
df = pd.DataFrame(events)
df
# Out:
#                                                event  \
# 0  {'event_id': 'EVT-10001', 'event_type': 'ORDER...
# 1  {'event_id': 'EVT-10002', 'event_type': 'ORDER...
# 2  {'event_id': 'EVT-10003', 'event_type': 'ORDER...
# 3  {'event_id': 'EVT-10004', 'event_type': 'ORDER...
# 4  {'event_id': 'EVT-10005', 'event_type': 'PAYME...
# 5  {'event_id': 'EVT-10006', 'event_type': 'ORDER...
# 6  {'event_id': 'EVT-10007', 'event_type': 'ORDER...
# 7  {'event_id': 'EVT-10008', 'event_type': 'REFUN...
# 8  {'event_id': 'EVT-10009', 'event_type': 'ORDER...
# 9  {'event_id': 'EVT-10010', 'event_type': 'ORDER...
#
#                                                order  \
# 0  {'order_id': 'ORD-10001', 'order_date': '2026-...
# 1  {'order_id': 'ORD-10002', 'order_date': '2026-...
# 2  {'order_id': 'ORD-10003', 'order_date': '2026-...
# 3  {'order_id': 'ORD-10004', 'order_date': '2026-...
# 4  {'order_id': 'ORD-10005', 'order_date': '2026-...
# 5  {'order_id': 'ORD-10006', 'order_date': '2026-...
# ...

# %%
all_events = map(lambda x: {"event_id": x["event"]["event_id"],"event_typex":x["event"]["event_type"],"event_timestamp":x["event"]["timestamp"],"event_source_application": x["event"]["source"]["application"],"event_source_version": x["event"]["source"]["version"],"event_source_device_type": x["event"]["source"]["device"]["type"],"event_source_device_os": x["event"]["source"]["device"]["os"],"event_source_device_os_version": x["event"]["source"]["device"]["os_version"]},events)
df = pd.DataFrame(all_events)
df
# Out:
#     event_id       event_typex       event_timestamp event_source_application  \
# 0  EVT-10001     ORDER_CREATED  2026-08-29T10:30:45Z                   mobile
# 1  EVT-10002     ORDER_UPDATED  2026-08-29T11:15:20Z                      web
# 2  EVT-10003   ORDER_CANCELLED  2026-08-29T12:05:10Z                   mobile
# 3  EVT-10004     ORDER_CREATED  2026-08-29T13:40:30Z                      web
# 4  EVT-10005    PAYMENT_FAILED  2026-08-29T14:25:45Z                   mobile
# 5  EVT-10006     ORDER_SHIPPED  2026-08-29T15:10:15Z                      web
# 6  EVT-10007   ORDER_DELIVERED  2026-08-29T16:20:00Z                   mobile
# 7  EVT-10008  REFUND_REQUESTED  2026-08-29T17:05:35Z                      web
# 8  EVT-10009     ORDER_CREATED  2026-08-29T18:15:45Z                   mobile
# 9  EVT-10010     ORDER_UPDATED  2026-08-29T19:00:10Z                      web
#
#   event_source_version event_source_device_type event_source_device_os  \
# ...

# %%
order = map(lambda x: {"order_id": x["order"]["order_id"],"order_date": x["order"]["order_date"],"status": x["order"]["status"],"currency": x["order"]["currency"],"customer": x["order"]["customer"],"payment":x["order"]["payment"],"items":x["order"]["items"],"metadata":x["metadata"]},events)

df = pd.DataFrame(order)
df
# Out:
#     order_id  order_date            status currency  \
# 0  ORD-10001  2026-08-29         CONFIRMED      INR
# 1  ORD-10002  2026-08-29           SHIPPED      INR
# 2  ORD-10003  2026-08-29         CANCELLED      INR
# 3  ORD-10004  2026-08-29         CONFIRMED      INR
# 4  ORD-10005  2026-08-29   PAYMENT_PENDING      INR
# 5  ORD-10006  2026-08-28           SHIPPED      INR
# 6  ORD-10007  2026-08-25         DELIVERED      INR
# 7  ORD-10008  2026-08-20  REFUND_REQUESTED      INR
# 8  ORD-10009  2026-08-29         CONFIRMED      INR
# 9  ORD-10010  2026-08-29        PROCESSING      INR
#
#                                             customer  \
# 0  {'customer_id': 'CUST-501', 'name': {'first': ...
# 1  {'customer_id': 'CUST-502', 'name': {'first': ...
# 2  {'customer_id': 'CUST-503', 'name': {'first': ...
# 3  {'customer_id': 'CUST-504', 'name': {'first': ...
# 4  {'customer_id': 'CUST-505', 'name': {'first': ...
# 5  {'customer_id': 'CUST-506', 'name': {'first': ...
# ...
